# %% [markdown]
# # Level 11: Testing Your Code
#
# ## 🛡️ Concept: Trust, but Verify
# How do you know your code works? You run it.
# But what if you change something later? How do you know you didn't break it?
#
# You write **Tests**.
# Tests are code that checks your code.

# %% [markdown]
# ### 🧪 The `unittest` Module
# Python comes with a built-in testing tool called `unittest`.

# %%
import unittest

# Here is a logical function: splitting a bar tab
def split_tab(total, people):
    if people <= 0:
        return 0
    return total / people

# Here is the Test Suite to prove it works
class TestTab(unittest.TestCase):

    def test_even_split(self):
        # $100 split by 2 people should be $50
        result = split_tab(100, 2)
        self.assertEqual(result, 50)
        
    def test_solo_drinker(self):
        # $30 tab for 1 person should be $30
        self.assertEqual(split_tab(30, 1), 30)

# This line runs the tests when you click Play
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK

# %%
# 🧪 BREAKDOWN OF UNIT TESTING:
# -------------------------
# 1. THE LAB (class TestTab): A class that groups all your experiments.
# 2. THE EXPERIMENTS (test_...): Every test function MUST start with 'test_'.
# 3. THE CHECKER (assertEqual): This compares the result to the expected answer.
# 4. THE START BUTTON (unittest.main): Runs the lab inside a notebook environment.

# %% [markdown]
# ## 🚦 Assertions
# The core of testing is the **Assertion**. It's a fancy way of saying "Check this."
#
# *   `assertEqual(a, b)`: Checks if a == b
# *   `assertTrue(x)`: Checks if x is True
# *   `assertIn(item, list)`: Checks if item is in the list

# %%
import unittest
# 🚀 MISSION: The Discount Checker

def apply_discount(price, code):
    if code == "SAVE10":
        return price - 10
    return price

# 1. Create a class called `TestDiscount`.
class TestDiscount(unittest.TestCase):
    def test_valid_code(self):
        Y = apply_discount(50,'SAVE10')
        self.assertEqual(Y,40)
# 2. Write a test called `test_valid_code`.
# 3. Assert that apply_discount(50, "SAVE10") equals 40.
# 4. Run the tests.
unittest.main(argv=['first'], exit = False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
