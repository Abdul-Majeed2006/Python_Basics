# %% [markdown]
# # Level 1: Variables and Simple Data Types
#
# ## 📦 Concept: Variables are Labels
# Imagine you are moving houses or packing for a big trip.
# A **variable** is just a focused label on a box.
#
# *   Box Content: A pair of hiking boots.
# *   Variable Name: `footwear`
#
# You don't need to know exactly *how* the box is made, you just need to know what's inside.

# %%
# Creating a variable (Assigning a value)
destination = "Paris"
days_remaining = 10

print(destination)
print(days_remaining)
# Out:
# Paris
# 10

# %% [markdown]
# ## 🧵 Strings (Text)
# Strings are just pieces of text. You can use single `' '` or double `" "` quotes.

# %%
city = "new york city"

# Methods: Tools to change the text
print(city.title()) # Capitalize Each Word
print(city.upper()) # YELL IT
print(city.lower()) # whisper it
# Out:
# New York City
# NEW YORK CITY
# new york city

# %% [markdown]
# ### f-strings (The Glue)
# The best way to mix variables into sentences.

# %%
first_name = "James"
last_name = "Bond"

# Look for the 'f' before the quotes
full_intro = f"The name is {last_name}. {first_name} {last_name}."
print(full_intro)
# Out:
# The name is Bond. James Bond.

# %% [markdown]
# ## 🔢 Numbers
# *   **Integers (int)**: Whole numbers. (Years, Count of people)
# *   **Floats (float)**: Decimals. (Money, Distance)

# %%
# Integers
salary = 85000
bonus = 5000
total_comp = salary + bonus
print(f"Total Comp: ${total_comp}")

# Floats
bill = 45.50
tip = bill * 0.20
print(f"Tip Amount: ${tip}")
# Out:
# Total Comp: $90000
# Tip Amount: $9.1

# %% [markdown]
# ### 💡 Underscores in Numbers
# You can use underscores to make big numbers readable. Python ignores them.

# %%
views = 1_000_000_000
print(views)
# Out:
# 1000000000

# %%
# 🚀 MISSION: The Digital Nomad Profile

# Create variables for:
# 1. name (String)
name = 'Zakari Abdul-Majeed'
# 2. current_city (String)
current_city = 'Abuja'
# 3. countries_visited (Integer)
Countries_visited = 2
# 4. remote_worker (Boolean - True or False)
remote_worker = False
# Use an f-string to print a sentence like:
# "Hi, I'm [Name] from [City]. I work remotely: [True/False]"
f"Hi, I'm {name} from {current_city}. I work remotely: {remote_worker}"
# Out:
# "Hi, I'm Zakari Abdul-Majeed from Abuja. I work remotely: False"
