# %% [markdown]
# # Phase 14: Real Applications 🌍
#
# > **Goal:** Become employable / competent.
#
# You now know `Syntax` + `Engineering Mindset`.
# You need **Context**. Pick ONE path.
#
# ## 1. Backend Engineering (APIs)
# **Tools:** FastAPI, Postgres, Docker
# **Project:** Build a ToDo API with user authentication and database persistence.
#
# ## 2. Data Engineering / Analysis
# **Tools:** Pandas, SQL, Airflow
# **Project:** Analyze 1GB of CSV data, clean it, and generate a report.
#
# ## 3. Automation / DevOps
# **Tools:** Python Scripts, GitHub Actions, AWS SDK (boto3)
# **Project:** A script that backups a folder to S3 every night and logs the result.
#
# ## Final Words:
# Building > Reading.
# Close this notebook and build something.
