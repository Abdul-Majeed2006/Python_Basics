# %% [markdown]
# # Level 4: If Statements
#
# ## 🚦 Concept: Flow Control
# Life is full of decisions: "If it rains, I'll take a taxi. Else, I'll walk."
# Python uses `if` statements to handle this logic.

# %%
# The Bouncer Logic
age = 20

if age >= 21:
    print("Welcome to the club! 🍸")
else:
    print("Sorry, come back when you're older.")
# Out:
# Sorry, come back when you're older.

# %% [markdown]
# ### 🛣️ Multiple Options (elif)
# What if there are more than two choices? Like a movie recommender.

# %%
genre = "Sci-Fi"

print(f"User likes: {genre}")

if genre == "Comedy":
    print("Recommended: 'The Office'")
elif genre == "Sci-Fi":
    print("Recommended: 'Interstellar'")
elif genre == "Horror":
    print("Recommended: 'The Conjuring'")
else:
    print("Recommended: 'Planet Earth'")
# Out:
# User likes: Sci-Fi
# Recommended: 'Interstellar'

# %% [markdown]
# ## 🤝 Logical Operators (and / or)
# Sometimes you need to check two things at once.

# %%
has_subscription = True
internet_connected = False

# AND: Both must be true
if has_subscription and internet_connected:
    print("Streaming Movie... 🍿")
else:
    print("Error: Check account or internet.")

# OR: At least one must be true
day = "Saturday"
if day == "Saturday" or day == "Sunday":
    print("It's the weekend! Sleep in.")
# Out:
# Error: Check account or internet.
# It's the weekend! Sleep in.

# %% [markdown]
# ### ✅ Checking a List
# Is an item in the list?

# %%
banned_users = ['troll123', 'spambot', 'hacker99']
user = 'alice_nyc'

if user not in banned_users:
    print(f"Access granted for {user}.")
else:
    print("Account suspended.")
# Out:
# Access granted for alice_nyc.

# %%
# 🚀 MISSION: The Restaurant Recommender

# 1. Create a variable `budget` (e.g., 20 or 50)
budget = 50
# 2. Write an if/elif/else chain:
if budget < 10:
    print('Grab a Taco')
#    - If budget < 10: Print "Grab a taco."
elif budget < 50:
    print('Italian Bistro')
#    - If budget < 50: Print "Italian Bistro."
else:
    print('Fancy Steakhouse')
#    - Else: Print "Fancy Steakhouse."
# Out:
# Fancy Steakhouse
