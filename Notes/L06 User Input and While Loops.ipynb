# %% [markdown]
# # Level 6: User Input and While Loops
#
# ## 🗣️ Concept: User Feedback
# Programs are useless if they can't take input.
# We use `input()` to ask questions.

# %%
# The program pauses here until the user types something and hits ENTER
name = input("Name for the reservation? ")

print(f"Table confirmed for {name}.")
# Out:
# Table confirmed for Abdul-Majeed.

# %% [markdown]
# ### ⚠️ Handling Numbers
# `input()` ALWAYS returns a **String** (text). If you want to do math (like splitting a bill), you must convert it.

# %%
bill = input("Total Bill Amount: $")
people = input("Split how many ways? ")

# Must convert text to floats/ints!
total = float(bill)
count = int(people)

per_person = total / count

print(f"Each person owes: ${per_person}")
# Out:
# Each person owes: $97.0

# %% [markdown]
# ----
# ## 🔄 While Loops
# A `for` loop runs for a set list.
# A `while` loop runs **until you tell it to stop**.
#
# Perfect for entering data until you are done.

# %%
# Interest Calculator
savings = 1000
year = 1

# Calculate untill we double our money
while savings < 2000:
    savings = savings * 1.05 # 5% Interest
    print(f"Year {year}: ${savings:.2f}")
    year += 1
# Out:
# Year 1: $1050.00
# Year 2: $1102.50
# Year 3: $1157.62
# Year 4: $1215.51
# Year 5: $1276.28
# Year 6: $1340.10
# Year 7: $1407.10
# Year 8: $1477.46
# Year 9: $1551.33
# Year 10: $1628.89
# Year 11: $1710.34
# Year 12: $1795.86
# Year 13: $1885.65
# Year 14: $1979.93
# Year 15: $2078.93

# %% [markdown]
# ### 🏳️ The Quit Condition
# Letting the user control when to stop.

# %%
active = True
guests = []

while active:
    name = input("Enter guest name (or 'quit' to finish): ")
    
    if name == 'quit':
        active = False # Stop the loop
    else:
        print(f"Added {name} to the list.")
        guests.append(name)

print(f"Final Guest List: {guests}")
# Out:
# Added sam to the list.
# Added dan to the list.
# Added grayson to the list.
# Added chaise to the list.
# Final Guest List: ['sam', 'dan', 'grayson', 'chaise']

# %%
# 🚀 MISSION: The Budget Tracker

# 1. Create a variable `total_spent = 0`
total_spent = float(0)
# 2. Use a Loop to ask "Enter expense amount (or '0' to stop): "
running = True
while running:
# 3. Add the amount to `total_spent`.
    spent = float(input('Enter how much did you spend today, or Enter 0 to quit'))
    total_spent += spent
    if spent == 0:
        running = False
# 4. When the loop ends, print formatting: "Total Spent: $[Amount]"
print(f'Total Spent: ${total_spent}')
# Out:
# Total Spent: $230.0
